# %%
# in late Aug 25 I used this and 'first_sqllite' ipynb files to learn about the 
# first steps of ETL for this MLB project
import requests

url = "https://statsapi.mlb.com/api/v1/teams"
response = requests.get(url)
data = response.json()

# %%
# Check the status code to make sure the request worked
print("Status Code:", response.status_code)

# See the top-level keys in the data
print("Top-level keys:", data.keys())

# See how many teams are in the list
print("Number of teams returned:", len(data["teams"]))

# Peek at the first team's data structure
print("First team keys:", data["teams"][0].keys())
# Out:
# Status Code: 200
# Top-level keys: dict_keys(['copyright', 'teams'])
# Number of teams returned: 790
# First team keys: dict_keys(['allStarStatus', 'id', 'name', 'link', 'season', 'venue', 'teamCode', 'fileCode', 'abbreviation', 'teamName', 'locationName', 'firstYearOfPlay', 'league', 'sport', 'shortName', 'parentOrgName', 'parentOrgId', 'franchiseName', 'clubName', 'active'])

# %%
import pandas as pd

# %%
df = pd.json_normalize(data["teams"])
sorted(df.columns)
# Out:
# ['abbreviation',
#  'active',
#  'allStarStatus',
#  'clubName',
#  'division.id',
#  'division.link',
#  'division.name',
#  'fileCode',
#  'firstYearOfPlay',
#  'franchiseName',
#  'id',
#  'league.id',
#  'league.link',
#  'league.name',
#  'link',
#  'locationName',
#  'name',
#  'parentOrgId',
#  'parentOrgName',
#  'season',
#  'shortName',
#  'sport.id',
#  'sport.link',
#  'sport.name',
#  'springLeague.abbreviation',
#  'springLeague.id',
#  'springLeague.link',
#  'springLeague.name',
#  'springVenue.id',
#  'springVenue.link',
#  'teamCode',
#  'teamName',
#  'venue.id',
#  'venue.link',
#  'venue.name']

# %%
df_active_mlb = df[
    (df["active"] == True) &
    (df["sport.name"] == "Major League Baseball")
]
df_active_mlb.head()
# Out:
#    allStarStatus   id                  name               link  season  \
# 20             N  108    Los Angeles Angels  /api/v1/teams/108    2025
# 21             N  109  Arizona Diamondbacks  /api/v1/teams/109    2025
# 22             N  110     Baltimore Orioles  /api/v1/teams/110    2025
# 23             N  111        Boston Red Sox  /api/v1/teams/111    2025
# 24             N  112          Chicago Cubs  /api/v1/teams/112    2025
#
#    teamCode fileCode abbreviation teamName locationName  ...  \
# 20      ana      ana          LAA   Angels      Anaheim  ...
# 21      ari      ari           AZ  D-backs      Phoenix  ...
# 22      bal      bal          BAL  Orioles    Baltimore  ...
# 23      bos      bos          BOS  Red Sox       Boston  ...
# 24      chn      chc          CHC     Cubs      Chicago  ...
#
#                sport.name division.id            division.name  \
# 20  Major League Baseball       200.0     American League West
# 21  Major League Baseball       203.0     National League West
# 22  Major League Baseball       201.0     American League East
# 23  Major League Baseball       201.0     American League East
# 24  Major League Baseball       205.0  National League Central
#
#             division.link springLeague.id  springLeague.name  \
# 20  /api/v1/divisions/200           114.0      Cactus League
# 21  /api/v1/divisions/203           114.0      Cactus League
# 22  /api/v1/divisions/201           115.0  Grapefruit League
# 23  /api/v1/divisions/201           115.0  Grapefruit League
# 24  /api/v1/divisions/205           114.0      Cactus League
#
#      springLeague.link  springLeague.abbreviation springVenue.id  \
# 20  /api/v1/league/114                         CL         2500.0
# 21  /api/v1/league/114                         CL         4249.0
# 22  /api/v1/league/115                         GL         2508.0
# 23  /api/v1/league/115                         GL         4309.0
# 24  /api/v1/league/114                         CL         4629.0
#
#        springVenue.link
# 20  /api/v1/venues/2500
# 21  /api/v1/venues/4249
# 22  /api/v1/venues/2508
# 23  /api/v1/venues/4309
# 24  /api/v1/venues/4629
#
# [5 rows x 35 columns]

# %%
print("Number of columns:", len(df.columns))
print("First 25 column names:", sorted(df.columns)[:25])
print("\nSample row data:")
print(df.iloc[0].to_dict())
# Out:
# Number of columns: 35
# First 25 column names: ['abbreviation', 'active', 'allStarStatus', 'clubName', 'division.id', 'division.link', 'division.name', 'fileCode', 'firstYearOfPlay', 'franchiseName', 'id', 'league.id', 'league.link', 'league.name', 'link', 'locationName', 'name', 'parentOrgId', 'parentOrgName', 'season', 'shortName', 'sport.id', 'sport.link', 'sport.name', 'springLeague.abbreviation']
#
# Sample row data:
# {'allStarStatus': 'N', 'id': 4104, 'name': 'Coastal Carolina Chanticleers', 'link': '/api/v1/teams/4104', 'season': 2025, 'teamCode': 'ccu', 'fileCode': 't4104', 'abbreviation': 'CCC', 'teamName': 'Chanticleers', 'locationName': 'United States', 'firstYearOfPlay': '2011', 'shortName': 'Coastal Carolina', 'parentOrgName': 'Office of the Commissioner', 'parentOrgId': 11.0, 'franchiseName': 'Coastal Carolina', 'clubName': 'Chanticleers', 'active': True, 'venue.id': 401, 'venue.name': 'TBD', 'venue.link': '/api/v1/venues/401', 'league.id': 107.0, 'league.name': 'College Baseball', 'league.link': '/api/v1/league/107', 'sport.id': 22, 'sport.link': '/api/v1/sports/22', 'sport.name': 'College Baseball', 'division.id': nan, 'division.name': nan, 'division.link': nan, 'springLeague.id': nan, 'springLeague.name': nan, 'springLeague.link': nan, 'springLeague.abbreviation': nan, 'springVenue.id': nan, 'springVenue.link': nan}

# %%
# sanity: these should already exist from earlier cells
assert "teams" in data and isinstance(data["teams"], list), "Missing/invalid `data`"
assert "id" in pd.json_normalize(data["teams"]).columns, "`df` needs to be rebuilt"

# rebuild df just in case
df = pd.json_normalize(data["teams"], max_level=2)

# %%
# filter to only include MLB teams here
df = df[df["sport.name"] == "Major League Baseball"]

#make a map (dictionary?) of names of columns you want to keep and what you want the name to be
keep_map = {
    "id": "team_id",
    "name": "team_name",
    "abbreviation": "abbrev",
    "teamCode": "team_code",
    "franchiseName": "franchise",
    "clubName": "club_name",
    "league.name": "league",
    "division.name": "division",
    "locationName": "location",
    "season": "season",
    "firstYearOfPlay": "first_year_of_play",
    "venue.name": "venue_name",
    "active": "active"
}

# %%
# filter down to columns that actually exist in df
existing = {k: v for k, v in keep_map.items() if k in df.columns}

# create clean table with only those columns, renamed
tidy = df[list(existing.keys())].rename(columns=existing)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

tidy
# Out:
#     team_id              team_name abbrev team_code      franchise  \
# 20      108     Los Angeles Angels    LAA       ana    Los Angeles
# 21      109   Arizona Diamondbacks     AZ       ari        Arizona
# 22      110      Baltimore Orioles    BAL       bal      Baltimore
# 23      111         Boston Red Sox    BOS       bos         Boston
# 24      112           Chicago Cubs    CHC       chn        Chicago
# 25      113        Cincinnati Reds    CIN       cin     Cincinnati
# 26      114    Cleveland Guardians    CLE       cle      Cleveland
# 27      115       Colorado Rockies    COL       col       Colorado
# 28      116         Detroit Tigers    DET       det        Detroit
# 29      117         Houston Astros    HOU       hou        Houston
# 30      118     Kansas City Royals     KC       kca    Kansas City
# 31      119    Los Angeles Dodgers    LAD       lan    Los Angeles
# 32      120   Washington Nationals    WSH       was     Washington
# 33      121          New York Mets    NYM       nyn       New York
# 39      133              Athletics    ATH       ath      Athletics
# 40      134     Pittsburgh Pirates    PIT       pit     Pittsburgh
# 41      135       San Diego Padres     SD       sdn      San Diego
# 42      136       Seattle Mariners    SEA       sea        Seattle
# 43      137   San Francisco Giants     SF       sfn  San Francisco
# 44      138    St. Louis Cardinals    STL       sln      St. Louis
# 45      139         Tampa Bay Rays     TB       tba      Tampa Bay
# 46      140          Texas Rangers    TEX       tex          Texas
# 47      141      Toronto Blue Jays    TOR       tor        Toronto
# 48      142        Minnesota Twins    MIN       min      Minnesota
# 49      143  Philadelphia Phillies    PHI       phi   Philadelphia
# 50      144         Atlanta Braves    ATL       atl        Atlanta
# 51      145      Chicago White Sox    CWS       cha        Chicago
# 52      146          Miami Marlins    MIA       mia          Miami
# 53      147       New York Yankees    NYY       nya       New York
# 56      158      Milwaukee Brewers    MIL       mil      Milwaukee
#
#        club_name           league                 division       location  \
# 20        Angels  American League     American League West        Anaheim
# 21  Diamondbacks  National League     National League West        Phoenix
# 22       Orioles  American League     American League East      Baltimore
# 23       Red Sox  American League     American League East         Boston
# 24          Cubs  National League  National League Central        Chicago
# 25          Reds  National League  National League Central     Cincinnati
# 26     Guardians  American League  American League Central      Cleveland
# 27       Rockies  National League     National League West         Denver
# 28        Tigers  American League  American League Central        Detroit
# 29        Astros  American League     American League West        Houston
# 30        Royals  American League  American League Central    Kansas City
# 31       Dodgers  National League     National League West    Los Angeles
# 32     Nationals  National League     National League East     Washington
# 33          Mets  National League     National League East       Flushing
# 39     Athletics  American League     American League West     Sacramento
# 40       Pirates  National League  National League Central     Pittsburgh
# 41        Padres  National League     National League West      San Diego
# 42      Mariners  American League     American League West        Seattle
# 43        Giants  National League     National League West  San Francisco
# 44     Cardinals  National League  National League Central      St. Louis
# 45          Rays  American League     American League East          Tampa
# 46       Rangers  American League     American League West      Arlington
# 47     Blue Jays  American League     American League East        Toronto
# 48         Twins  American League  American League Central    Minneapolis
# 49      Phillies  National League     National League East   Philadelphia
# 50        Braves  National League     National League East        Atlanta
# 51     White Sox  American League  American League Central        Chicago
# 52       Marlins  National League     National League East          Miami
# 53       Yankees  American League     American League East          Bronx
# 56       Brewers  National League  National League Central      Milwaukee
#
#     season first_year_of_play                    venue_name  active
# 20    2025               1961                 Angel Stadium    True
# 21    2025               1996                   Chase Field    True
# 22    2025               1901   Oriole Park at Camden Yards    True
# 23    2025               1901                   Fenway Park    True
# 24    2025               1874                 Wrigley Field    True
# 25    2025               1882      Great American Ball Park    True
# 26    2025               1901             Progressive Field    True
# 27    2025               1992                   Coors Field    True
# 28    2025               1901                 Comerica Park    True
# 29    2025               1962                   Daikin Park    True
# 30    2025               1968              Kauffman Stadium    True
# 31    2025               1884                Dodger Stadium    True
# 32    2025               1968                Nationals Park    True
# 33    2025               1962                    Citi Field    True
# 39    2025               1901            Sutter Health Park    True
# 40    2025               1882                      PNC Park    True
# 41    2025               1968                    Petco Park    True
# 42    2025               1977                 T-Mobile Park    True
# 43    2025               1883                   Oracle Park    True
# 44    2025               1892                 Busch Stadium    True
# 45    2025               1996  George M. Steinbrenner Field    True
# 46    2025               1961              Globe Life Field    True
# 47    2025               1977                 Rogers Centre    True
# 48    2025               1901                  Target Field    True
# 49    2025               1883            Citizens Bank Park    True
# 50    2025               1871                   Truist Park    True
# 51    2025               1901                    Rate Field    True
# 52    2025               1991                loanDepot park    True
# 53    2025               1903                Yankee Stadium    True
# 56    2025               1968         American Family Field    True

# %%
# Convert IDs and years to numeric, booleans to proper True/False
tidy["team_id"] = pd.to_numeric(tidy["team_id"], errors="coerce").astype("Int64")

if "season" in tidy.columns:
    tidy["season"] = pd.to_numeric(tidy["season"], errors="coerce").astype("Int64")

if "first_year_of_play" in tidy.columns:
    tidy["first_year_of_play"] = pd.to_numeric(tidy["first_year_of_play"], errors="coerce").astype("Int64")

if "active" in tidy.columns:
    tidy["active"] = tidy["active"].astype("boolean")

tidy.dtypes
# Out:
# team_id                 Int64
# team_name              object
# abbrev                 object
# team_code              object
# franchise              object
# club_name              object
# league                 object
# division               object
# location               object
# season                  Int64
# first_year_of_play      Int64
# venue_name             object
# active                boolean
# dtype: object

# %%
len(tidy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(tidy)
#
# NameError: name 'tidy' is not defined
